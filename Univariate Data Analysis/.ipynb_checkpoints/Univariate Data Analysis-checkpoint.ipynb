# %% [markdown]
# Importing Libraries

# %%
import os
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Change Working dircetory

os.chdir("C:\\Users\\kumarma\\My Codebase\\Univariate Data Analysis");

# %%
#Read the data file
df=pd.read_excel("Sample-Superstore-Subset-Excel.xlsx")

# %%
df.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category   ...     \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies   ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies   ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies   ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies   ...
# 4    Bonnie Potter  Express Air        Corporate       Technology   ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
#Shows Summary Statistics
df.describe()
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   9426.000000  9426.000000  9426.000000    9426.000000  9426.000000
# mean   20241.015277     0.049628    88.303686      12.795142  1738.422236
# std     6101.890965     0.031798   281.540982      17.181203   979.167197
# min        2.000000     0.000000     0.990000       0.490000     2.000000
# 25%    19330.250000     0.020000     6.480000       3.192500   898.000000
# 50%    21686.500000     0.050000    20.990000       6.050000  1750.000000
# 75%    24042.750000     0.080000    85.990000      13.990000  2578.750000
# max    26399.000000     0.250000  6783.020000     164.730000  3403.000000
#
#        Product Base Margin   Postal Code        Profit  Quantity ordered new  \
# count          9354.000000   9426.000000   9426.000000           9426.000000
# mean              0.512189  52446.327286    139.236410             13.798430
# ...

# %%
#Shows Summary Statistics
df.describe()
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   9426.000000  9426.000000  9426.000000    9426.000000  9426.000000
# mean   20241.015277     0.049628    88.303686      12.795142  1738.422236
# std     6101.890965     0.031798   281.540982      17.181203   979.167197
# min        2.000000     0.000000     0.990000       0.490000     2.000000
# 25%    19330.250000     0.020000     6.480000       3.192500   898.000000
# 50%    21686.500000     0.050000    20.990000       6.050000  1750.000000
# 75%    24042.750000     0.080000    85.990000      13.990000  2578.750000
# max    26399.000000     0.250000  6783.020000     164.730000  3403.000000
#
#        Product Base Margin   Postal Code        Profit  Quantity ordered new  \
# count          9354.000000   9426.000000   9426.000000           9426.000000
# mean              0.512189  52446.327286    139.236410             13.798430
# ...

# %%
#Drop Column named Row ID
df = df.drop(['Row ID'], axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 23 columns):
# Order Priority          9426 non-null object
# Discount                9426 non-null float64
# Unit Price              9426 non-null float64
# Shipping Cost           9426 non-null float64
# Customer ID             9426 non-null int64
# Customer Name           9426 non-null object
# Ship Mode               9426 non-null object
# Customer Segment        9426 non-null object
# Product Category        9426 non-null object
# Product Sub-Category    9426 non-null object
# Product Container       9426 non-null object
# Product Name            9426 non-null object
# Product Base Margin     9354 non-null float64
# Region                  9426 non-null object
# State or Province       9426 non-null object
# City                    9426 non-null object
# Postal Code             9426 non-null int64
# Order Date              9426 non-null datetime64[ns]
# ...

# %%
#Shows No of Columns and Rows
df.shape
# Out:
# (9426, 23)

# %%
#De-dupe records
df.drop_duplicates(keep='first')
# Out:
#      Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     Not Specified      0.01        2.88           0.50            2
# 1              High      0.01        2.84           0.93            3
# 2     Not Specified      0.03        6.68           6.15            3
# 3     Not Specified      0.01        5.68           3.60            3
# 4     Not Specified      0.00      205.99           2.50            3
# 5            Medium      0.09       55.48          14.30            3
# 6               Low      0.08      120.97          26.30            3
# 7     Not Specified      0.02      500.98          26.00            5
# 8               Low      0.08        6.48           6.81            5
# 9              High      0.01       90.24           0.99            6
# 10         Critical      0.07        6.48           6.60            6
# 11         Critical      0.01        4.84           0.71            6
# ...

# %%
df.shape
# Out:
# (9426, 23)

# %%
df.count()
# Out:
# Order Priority          9426
# Discount                9426
# Unit Price              9426
# Shipping Cost           9426
# Customer ID             9426
# Customer Name           9426
# Ship Mode               9426
# Customer Segment        9426
# Product Category        9426
# Product Sub-Category    9426
# Product Container       9426
# Product Name            9426
# Product Base Margin     9354
# Region                  9426
# State or Province       9426
# City                    9426
# Postal Code             9426
# Order Date              9426
# Ship Date               9426
# Profit                  9426
# Quantity ordered new    9426
# Sales                   9426
# Order ID                9426
# dtype: int64

# %%
df.max()
# Out:
# Order Priority                         Not Specified
# Discount                                        0.25
# Unit Price                                   6783.02
# Shipping Cost                                 164.73
# Customer ID                                     3403
# Customer Name                             Zachary Yu
# Ship Mode                                Regular Air
# Customer Segment                      Small Business
# Product Category                          Technology
# Product Sub-Category    Telephones and Communication
# Product Container                           Wrap Bag
# Product Name                                iDENi80s
# Product Base Margin                             0.85
# Region                                          West
# State or Province                            Wyoming
# City                                            Yuma
# Postal Code                                    99362
# Order Date                       2013-12-31 00:00:00
# ...

# %%
df.min()
# Out:
# Order Priority                                                   Critical
# Discount                                                                0
# Unit Price                                                           0.99
# Shipping Cost                                                        0.49
# Customer ID                                                             2
# Customer Name                                          Aaron Davies Bruce
# Ship Mode                                                  Delivery Truck
# Customer Segment                                                 Consumer
# Product Category                                                Furniture
# Product Sub-Category                                           Appliances
# Product Container                                               Jumbo Box
# Product Name            "While you Were Out" Message Book, One Form pe...
# Product Base Margin                                                  0.35
# ...

# %%
df.std()
# Out:
# Discount                    0.031798
# Unit Price                281.540982
# Shipping Cost              17.181203
# Customer ID               979.167197
# Product Base Margin         0.135229
# Postal Code             29374.597802
# Profit                    998.486483
# Quantity ordered new       15.107688
# Sales                    2598.019818
# Order ID                19149.448857
# dtype: float64

# %%
#Function to draw Histogram and Blxplot for all Measures and Bar Graph for all the Dimensions

def analyze_data (df):
    import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt
    import seaborn as sns
    

    for i in list (df.columns):
        #Histogram and #BoxPlot
        if (df[i].dtype in ['float64','int64']):
            df.hist(column=i,grid=False,figsize=(10,8))
            plt.savefig(str(i)+"_histogram.png")
            #plt.show()
            plt.close()
        #Box Plot
            df.boxplot(column=i,grid=False,figsize=(10,8))
            plt.savefig(str(i)+"_boxplot.png")
            plt.close()
        else:
        #Bar Graph
            sns.countplot(df[i])
            plt.savefig(str(i)+"_bar_graph.png")
            plt.close()

# %%
analyze_data(df)

# %%
#Creating the summary file
x=df[df.columns].describe(include='all')
x.to_csv('summary.csv')

# %%
#Finding count of the missing values
row=['missing values']
for i in list(df.columns):
    row.append(df[i].isnull().sum())

with open('summary.csv','a') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(row)
csvfile.close()

# %%
#Finding the count of outliers
row1=['outliers']
for i in list(df.columns):
    if df[i].dtype in ('int64', 'float64'):
        # df.Age > (df.loc[:,"Age"].mean() +  (df.loc[:,"Age"].std()*3))
        row1.append((df[i] > (df.loc[:,i].mean() + (df.loc[:,i].std()*3))).sum())
    else:
        row1.append('NA')
        
with open('summary.csv','a') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(row1)
csvfile.close()
